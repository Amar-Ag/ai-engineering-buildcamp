# %%
from groq import Groq
from dotenv import load_dotenv
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages = [{"role": "user", "content": "tell me a joke about Alexey"}]
)

# %%
print(response.choices[0].message.content)
# Out:
# Why did Alexey bring a ladder to the party? Because he heard the drinks were on the house.

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-22eab802-e734-4fae-af76-f8ed62734809",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "Why did Alexey bring a ladder to the party? Because he heard the drinks were on the house.",
#         "role": "assistant",
#         "annotations": null,
#         "executed_tools": null,
#         "function_call": null,
#         "reasoning": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1776691664,
#   "model": "llama-3.3-70b-versatile",
#   "object": "chat.completion",
#   "mcp_list_tools": null,
#   "service_tier": "on_demand",
#   "system_fingerprint": "fp_f8b414701e",
#   "usage": {
#     "completion_tokens": 22,
#     "prompt_tokens": 42,
#     "total_tokens": 64,
#     "completion_time": 0.06826638,
#     "completion_tokens_details": null,
#     "prompt_time": 0.005695959,
#     "prompt_tokens_details": null,
#     "queue_time": 0.149534822,
#     "total_time": 0.073962339
#   },
#   "usage_breakdown": null,
#   "x_groq": {
#     "id": "req_01kpnh6npdf82a42n4wt047bnn",
#     "debug": null,
#     "seed": 158058734,
#     "usage": null
#   }
# }

# %%
response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages = [{"role": "user", "content": "tell me a bad time story about a unicorn"}]
)

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=353, prompt_tokens=44, total_tokens=397, completion_time=1.439325154, completion_tokens_details=None, prompt_time=0.001976623, prompt_tokens_details=None, queue_time=0.043105142, total_time=1.441301777)

# %%
MODEL_PRICES = {
    "llama-3.3-70b-versatile": {"input":0.59, "output":0.79}
}

# %%
def calculate_cost(model_name: str, input_tokens: int, output_tokens: int) -> float:
    prices = MODEL_PRICES[model_name.lower()]
    input_cost = (input_tokens / 1_000_000) * prices["input"]
    output_cost = (output_tokens / 1_000_000) * prices["output"]
    return input_cost + output_cost

# %%
usage = response.usage

cost = calculate_cost(
    model_name="llama-3.3-70b-versatile",
    input_tokens=usage.prompt_tokens,
    output_tokens=usage.completion_tokens
)

print(f"Cost: ${cost:.6f}")
# Out:
# Cost: $0.000305

# %%
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a land far, far away, there was a unicorn named Gary. Gary was a bit of an oddball in the unicorn world. While his fellow unicorns were content to prance around, spreading joy and magic wherever they went, Gary was more interested in eating beans and watching TV on the couch.
#
# One day, Gary woke up feeling particularly gassy. He had eaten a large can of beans for breakfast, and it was not agreeing with him. As he stumbled out of his cave, he let out a massive fart that echoed through the valley.
#
# The other unicorns were shocked and offended by Gary's behavior. "Gary, how could you?" they cried. "You're a unicorn, for sparkles sake! You're supposed to be magical and majestic, not gassy and gross!"
#
# Gary just shrugged and said, "Hey, a unicorn's gotta do what a unicorn's gotta do." But as he continued to fart his way through the day, the other unicorns began to avoid him.
#
# Things only got worse from there. Gary's farts became so potent that they started to melt the flowers and burn the grass. The other unicorns were forced to evacuate the area, and Gary was left all alone, surrounded by a cloud of noxious gas.
#
# As the days passed, Gary's farts only grew stronger. He became known as the "Turdicorn," and his reputation spread far and wide. No one wanted to be near him, and Gary was left to live out the rest of his days in solitude, surrounded by his own stinky fumes.
#
# And that, my friends, is the story of Gary the Turdicorn, the unicorn who let his love of beans ruin his life.

# %%
stream = response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages = [{"role": "user", "content": "tell me a bad time story about a unicorn"}],
    stream= True
)

response = None
events = []
for event in stream:
    events.append(event)
    if event.choices[0].delta.content:
        print(event.choices[0].delta.content, end='')
# Out:
# Once upon a time, in a land far, far away, there was a unicorn named Gary. Gary was not your typical unicorn - he was grumpy, smelled like rotten fish, and had a penchant for playing the accordion at 3 am.
#
# Every morning, the other unicorns in the forest would wake up to the sound of Gary's off-key accordion playing, and they would all cover their ears in unison. The noise was so bad that it would make the birds stop singing, the flowers wilt, and the sun hide behind the clouds.
#
# One day, the other unicorns had had enough of Gary's antics, and they decided to stage an intervention. They gathered around him and said, "Gary, dear Gary, please for the love of all things magical, stop playing that accordion!"
#
# But Gary just scowled and said, "You're all just jealous of my unique talent!" And with that, he began to play an even louder, more ear-piercing rendition of "Who Let the Dogs Out" on his accordion.
#
# The other unicorns were horrified, and they decided to take drastic measures. They called in a team of highly trained, ninja-like fairies to steal Gary's accordion and replace it with a nice, quiet harmonica.
#
# But Gary was not one to be outsmarted. He had secretly been taking lessons in the dark art of "extreme knitting," and he had created a massive, accordion-shaped sweater that would amplify his playing to ear-shattering decibels.
#
# The fairies tried to reason with Gary, but he just put on his sweater and began to play a deafening solo that shattered all the windows in the forest, sent the birds fleeing, and caused the trees to tremble with fear.
#
# And from that day on, Gary was known as the unicorn who single-handedly destroyed the peace and quiet of the forest with his awful accordion playing. The other unicorns learned to wear earplugs at all times, and the fairies never forgot the terror of Gary's extreme knitting skills.

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Amar"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 👋 Hello Amar 🤗, it's nice to meet you 🌟. How are you doing today 🤔? 🌞

# %%
response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "What is my name?"}],
)
print(response.choices[0].message.content)
# Out:
# I don't know your name. I'm a large language model, I don't have any information about you, including your name, unless you tell me. If you'd like to share your name, I'd be happy to chat with you and address you by name.

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Amar"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 👋 Hello Amar 👋, it's nice to meet you 🤗. How can I help you today 🤔?

# %%
messages = [
    {"role": "system", "content": "make sure to add emojis"},
    {"role": "user", "content": "my name is Amar"},
]

# %%
messages
# Out:
# [{'role': 'system', 'content': 'make sure to add emojis'},
#  {'role': 'user', 'content': 'my name is Amar'}]

# %%
messages.append({
    "role": "assistant",
    "content": response.choices[0].message.content
})

messages.append({
    "role": "user",
    "content": "what's my name?"
})

# %%
response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 😊 Your name is Amar 👍. I remember 🙏.
